# %% [markdown]
# #**UADE**
# **FACULTAD DE INGENIERÍA Y CIENCIAS EXACTAS**
#
# **Departamento de Ingeniería (DETIN)**

# %% [markdown]
# #**<font color='cyan'>UADE - Introducción a la algoritmia</font>**

# %% [markdown]
# #**Primer parcial - 25/04/2022**

# %% [markdown]
# A partir de esta celda poné tu resolución del TP
#
# Alumno: Apellido/s, Nombre/s
#
# Legajo:

# %%
#Ej 01
"""
"""
num = 0
while num != -1:
    num = int(input("Ingrese un numero "))
    if num % 3 == 0:
        print(f'El numero {num} ingresado es multiplo de 3')
    elif num == -1:
        print('Adios')
    else: print(f'El numero {num} no es multiplo de 3')
# Out:
# Ingrese un numero 10
# El numero 10 no es multiplo de 3
# Ingrese un numero 15
# El numero 15 ingresado es multiplo de 3
# Ingrese un numero -1
# Adios

# %%
#Ej 02
"""
"""
hora = int(input("Ingrese hora "))
if hora < 0 or hora > 23 and hora != 0:
    print('Hora no valida')
elif hora < 13 and hora > 0:
    print('Es mañana')
elif hora >= 13 and hora <= 20:
    print('Es tarde')
elif hora > 20 or hora == 0 or hora == 00:
    print('Es noche')
# Out:
# Ingrese hora 12
# Es mañana

# %%
#Ej 03
"""
"""
Horas = int(input("Ingrese hora"))
Minutos = int(input("Ingrese minutos"))
if Horas < 0 or Horas > 23 or Minutos < 0 or Minutos > 59:
    print('Hora no valida')
else:
    print('Hora valida')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# ...

# %%
#Ej 04
"""
Ejercicio 4: (20 puntos) 

Solicitar al usuario 20 (5) números. Al finalizar informar por pantalla la cantidad de números ingresados que son múltiplos de 6. 

 
"""
contador = 0
for j in range(20):
    num = int(input("Ingrese el numero"))
    if num % 6 == 0:
        contador = contador + 1 
print(f'Hay {contador} numeros multiplos de 6 de los 20 ingresados')
# Out:
# Ingrese el numero6
# Ingrese el numero12
# Ingrese el numero24
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Ingrese el numero3
# Hay 3 numeros multiplos de 6 de los 20 ingresados

# %%
#Ej 05
"""
Ejercicio 5: (30 puntos) 

Le solicitan desarrolle una aplicación para una empresa de logística. El sistema primero deberá solicitar al usuario la cantidad de paquetes a enviar. Luego solicitar para cada paquete el peso, volumen (cm3) y distancia expresada en kilómetros hasta el destino. 

En base a los datos ingresados del paquete, se deberá calcular el importe a cobrar, que se calculará de la siguiente manera:  

importe = 200 + peso * 10 + volumen * 2 + importe * kilómetros 

y el importe del precio por kilómetros es: 

    • Menos de 60km: $100 

    • Entre 60 km y 500 km: $300 

    • Más de 500km: $500 

Una vez calculado el importe, informar por pantalla al usuario y solicitar los datos del próximo paquete. 

Al finalizar la carga de todos los paquetes informar por pantalla la suma de todos los importes calculados. 

 

Valores para hacer la prueba:  

Paquete 1 – Peso: 400 – Vol: 3 – Dist: 500 

Paquete 2 – Peso: 200 – Vol: 5 – Dist: 45 
"""
num_paq = 1 

importe = 0 

km_precio = 0 

precio_total = 0 

cant_paq = int(input('Ingrese la cantidad de paquetes a enviar: ')) 

while cant_paq < 1: 

    print('Puso un valor incorrecto') 

    cant_paq = int(input('Ingrese la cantidad de paquetes a enviar: ')) 

print() 

while num_paq <= cant_paq: 

    print('Para el paquete número', num_paq, 'ingrese') 

    # No hago validación de los valores que se ingresan a continuación 

    peso_paq = int(input('Cuánto pesa el paquete: ')) 

    vol_paq = int(input('Cuál es el volumen del paquete: ')) 

    km_paq = int(input('A qué distancia va el paquete: ')) 
#Saco precio del envio en base a los kilometros para despues sumarlo al importe del paquete
    if km_paq < 60: 

        km_precio = 100 

    elif km_paq > 60 and km_paq < 500: 

        km_precio = 300 

    elif km_paq > 500: 

        km_precio = 500

    importe = 200 + peso_paq * 10 + vol_paq * 2 + km_precio #km_precio representa el precio del envio en base a los kilometros recorridos

    print(f'El precio del paquete número {num_paq} es ${importe}') 

    print() 

    precio_total += importe 

    num_paq += 1 

print(f'El importe total a pagar es $ {precio_total}') 

print() 

print('No hay más paquetes que despachar, hasta mañana!')
# Out:
# Ingrese la cantidad de paquetes a enviar: 1
#
# Para el paquete número 1 ingrese
# Cuánto pesa el paquete: 400
# Cuál es el volumen del paquete: 3
# A qué distancia va el paquete: 500
# El precio del paquete número 1 es $4206
#
# El importe total a pagar es $ 4206
#
# No hay más paquetes que despachar, hasta mañana!
